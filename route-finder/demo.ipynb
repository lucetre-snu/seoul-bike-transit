# %%
# !fusermount -u drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/seoul-bike-transit/route-finder"
# %ls -la
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/seoul-bike-transit/route-finder
# total 74
# -rw------- 1 root root  1659 May 27 01:22 coordinate.py
# drwx------ 2 root root  4096 May 27 01:22 data/
# -rw------- 1 root root 20371 May 27 01:55 demo.ipynb
# -rw------- 1 root root  3988 May 27 01:55 demo.py
# -rw------- 1 root root    51 May 19 09:09 .env
# -rw------- 1 root root     4 May 27 01:22 .gitignore
# -rw------- 1 root root 29062 May 27 01:22 navigator.ipynb
# -rw------- 1 root root  5633 May 27 01:29 navigator.py
# drwx------ 2 root root  4096 May 27 01:55 __pycache__/
# drwx------ 2 root root  4096 May 27 01:22 routes/

# %%
# !pip install python-dotenv haversine pandas tqdm pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import demo
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    # demo.read_routes('강변역', '쥬티클럽')
    df = demo.read_routes('건대입구', '쥬티클럽')
    # demo.read_routes('반포한강공원', '여의도한강공원')
    # demo.read_routes('대한건축학회', '서울대학교 자하연')
    # demo.read_routes('낙성대공원', '몰로코')
    # demo.read_routes('삼성고', '서울신림초')
    # demo.read_routes('서울시청', '서울고속터미널')

df
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>org</th>
#       <th>srt_time</th>
#       <th>srt_calo</th>
#       <th>srt_dist</th>
#       <th>srt_name</th>
#       <th>bike_time</th>
#       <th>bike_calo</th>
#       <th>bike_dist</th>
#       <th>end_name</th>
#       <th>end_time</th>
#       <th>end_calo</th>
#       <th>end_dist</th>
#       <th>des</th>
#       <th>total_time</th>
#       <th>total_calo</th>
#       <th>total_dist</th>
#     </tr>
#     <tr>
#       <th>route_id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0-16</th>
# ...
