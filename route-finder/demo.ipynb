# %% [markdown]
# ---
#
# ## **START_OF_COLAB_NOTEBOOK_CODE**

# %%
# !fusermount -u drive
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/seoul-bike-transit/route-finder"

# %% [markdown]
# ## **END_OF_COLAB_NOTEBOOK_CODE**
#
# ---

# %%
# !pip install python-dotenv haversine pandas tqdm pickle5

# %%
import demo
import warnings
from IPython.display import HTML
from google.colab import data_table
from bs4 import BeautifulSoup

def optimize_routes(org, des):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)
        return demo.read_routes(org, des)

def render_dtbl(df_org):
    df = df_org.copy()
    for col in 'srt_tran end_tran srt_calo end_calo bike_calo'.split():
        try: del df[col]
        except: pass
    for id, row in df.iterrows():
        df.loc[id, 'org'] = BeautifulSoup(row['org']).text
        df.loc[id, 'des'] = BeautifulSoup(row['des']).text
        df.loc[id, 'srt_name'] = BeautifulSoup(row['srt_name']).text
        df.loc[id, 'end_name'] = BeautifulSoup(row['end_name']).text
    return data_table.DataTable(df, include_index=False, num_rows_per_page=10)

def render_html(df_org, by="time", ascending=True):
    df = df_org.copy()
    for col in df.columns:
        if col.find('tran') != -1 or col.find('time') != -1 or col.find('dist') != -1 or col.find('fare') != -1 or col.find('calo') != -1:
            if col.find(by) == -1 and col.find('total') == -1:
                try: del df[col]
                except: pass
    return HTML(df.sort_values(by=f'total_{by}', ascending=ascending).head().to_html(escape=False))

df = optimize_routes('대한건축학회', '서울대학교 자하연')
# df = optimize_routes('반포한강공원', '여의도한강공원')
# df = optimize_routes('낙성대공원', '몰로코')
# df = optimize_routes('삼성고', '서울신림초')
# df = optimize_routes('서울시청', '서울고속터미널')
# df = optimize_routes('건대입구', '쥬티클럽')

# %%
render_dtbl(df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>org</th>
#       <th>srt_time</th>
#       <th>srt_dist</th>
#       <th>srt_fare</th>
#       <th>srt_name</th>
#       <th>bike_time</th>
#       <th>bike_dist</th>
#       <th>bike_fare</th>
#       <th>end_name</th>
#       <th>end_time</th>
#       <th>end_dist</th>
#       <th>end_fare</th>
#       <th>des</th>
#       <th>total_time</th>
#       <th>total_calo</th>
#       <th>total_dist</th>
#       <th>total_fare</th>
#       <th>total_tran</th>
#     </tr>
#     <tr>
#       <th>route_id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5-16</th>
#       <td>대한건축학회</td>
#       <td>0:13:00</td>
#       <td>2.8</td>
#       <td>1200</td>
#       <td>JK장평타워</td>
#       <td>0:08:00</td>
#       <td>1.500</td>
#       <td>1000</td>
#       <td>낙성대 교수아파트</td>
#       <td>0:14:00</td>
#       <td>1.9</td>
#       <td>900</td>
#       <td>서울대학교 자하연</td>
#       <td>0:35:00</td>
#       <td>48</td>
#       <td>6.200</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5-14</th>
#       <td>대한건축학회</td>
#       <td>0:13:00</td>
#       <td>2.8</td>
#       <td>1200</td>
#       <td>JK장평타워</td>
#       <td>0:06:00</td>
#       <td>1.200</td>
#       <td>1000</td>
#       <td>영어마을 관악캠프</td>
#       <td>0:17:00</td>
#       <td>2.8</td>
#       <td>900</td>
#       <td>서울대학교 자하연</td>
#       <td>0:36:00</td>
#       <td>39</td>
#       <td>6.800</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2-3</th>
#       <td>대한건축학회</td>
#       <td>0:06:00</td>
#       <td>0.9</td>
#       <td>900</td>
#       <td>연세사랑병원신관앞</td>
#       <td>0:03:00</td>
#       <td>0.549</td>
#       <td>1000</td>
#       <td>사당역 5번출구</td>
#       <td>0:28:00</td>
#       <td>5.6</td>
#       <td>1200</td>
#       <td>서울대학교 자하연</td>
#       <td>0:37:00</td>
#       <td>17</td>
#       <td>7.049</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6-16</th>
#       <td>대한건축학회</td>
#       <td>0:16:00</td>
#       <td>3.1</td>
#       <td>1200</td>
#       <td>낙성대역 3번출구 뒤</td>
#       <td>0:07:00</td>
#       <td>1.300</td>
#       <td>1000</td>
#       <td>낙성대 교수아파트</td>
#       <td>0:14:00</td>
#       <td>1.9</td>
#       <td>900</td>
#       <td>서울대학교 자하연</td>
#       <td>0:37:00</td>
#       <td>48</td>
#       <td>6.300</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5-15</th>
#       <td>대한건축학회</td>
#       <td>0:13:00</td>
#       <td>2.8</td>
#       <td>1200</td>
#       <td>JK장평타워</td>
#       <td>0:09:00</td>
#       <td>1.600</td>
#       <td>1000</td>
#       <td>낙성대 과학전시관</td>
#       <td>0:15:00</td>
#       <td>1.9</td>
#       <td>900</td>
#       <td>서울대학교 자하연</td>
#       <td>0:37:00</td>
#       <td>53</td>
#       <td>6.300</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1-17</th>
#       <td>대한건축학회</td>
#       <td>0:06:00</td>
#       <td>0.7</td>
#       <td>1200</td>
#       <td>LG유플러스 (방배사옥)</td>
#       <td>0:35:00</td>
#       <td>6.100</td>
#       <td>1000</td>
#       <td>서울대학교 정문</td>
#       <td>0:12:00</td>
#       <td>1.3</td>
#       <td>1200</td>
#       <td>서울대학교 자하연</td>
#       <td>0:53:00</td>
#       <td>214</td>
#       <td>8.100</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>0-9</th>
#       <td>대한건축학회</td>
#       <td>0:04:00</td>
#       <td>0.4</td>
#       <td>900</td>
#       <td>방배역 2번 출구</td>
#       <td>0:24:00</td>
#       <td>4.200</td>
#       <td>1000</td>
#       <td>사랑의병원</td>
#       <td>0:26:00</td>
#       <td>3.1</td>
#       <td>900</td>
#       <td>서울대학교 자하연</td>
#       <td>0:54:00</td>
#       <td>143</td>
#       <td>7.700</td>
#       <td>1000</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>8-9</th>
#       <td>대한건축학회</td>
#       <td>0:24:00</td>
#       <td>4.4</td>
#       <td>1200</td>
#       <td>중앙동 동진빌딩</td>
#       <td>0:04:00</td>
#       <td>0.856</td>
#       <td>1000</td>
#       <td>사랑의병원</td>
#       <td>0:26:00</td>
#       <td>3.1</td>
#       <td>900</td>
#       <td>서울대학교 자하연</td>
#       <td>0:54:00</td>
#       <td>25</td>
#       <td>8.356</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3-17</th>
#       <td>대한건축학회</td>
#       <td>0:12:00</td>
#       <td>1.4</td>
#       <td>900</td>
#       <td>사당역 5번출구</td>
#       <td>0:30:00</td>
#       <td>4.900</td>
#       <td>1000</td>
#       <td>서울대학교 정문</td>
#       <td>0:12:00</td>
#       <td>1.3</td>
#       <td>1200</td>
#       <td>서울대학교 자하연</td>
#       <td>0:54:00</td>
#       <td>178</td>
#       <td>7.600</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>0-17</th>
#       <td>대한건축학회</td>
#       <td>0:04:00</td>
#       <td>0.4</td>
#       <td>900</td>
#       <td>방배역 2번 출구</td>
#       <td>0:40:00</td>
#       <td>6.500</td>
#       <td>1000</td>
#       <td>서울대학교 정문</td>
#       <td>0:12:00</td>
#       <td>1.3</td>
#       <td>1200</td>
#       <td>서울대학교 자하연</td>
#       <td>0:56:00</td>
#       <td>237</td>
#       <td>8.200</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <p>153 rows × 18 columns</p>
# </div>

# %%
render_html(df, 'time', ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>org</th>
#       <th>srt_time</th>
#       <th>srt_name</th>
#       <th>bike_time</th>
#       <th>end_name</th>
#       <th>end_time</th>
#       <th>des</th>
#       <th>total_time</th>
#       <th>total_calo</th>
#       <th>total_dist</th>
#       <th>total_fare</th>
#       <th>total_tran</th>
#     </tr>
#     <tr>
#       <th>route_id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5-16</th>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,492341.0,1104736.0&rt1=대한건축학회&rt2=JK장평타워">대한건축학회</a></td>
#       <td>0:13:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=bike&rt=492341.0,1104736.0,490636.0,1102650.0&rt1=JK장평타워&rt2=낙성대 교수아파트">JK장평타워</a></td>
#       <td>0:08:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=490636.0,1102650.0,489405.0,1100357.0&rt1=낙성대 교수아파트&rt2=서울대학교 자하연">낙성대 교수아파트</a></td>
#       <td>0:14:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,489405.0,1100357.0&rt1=대한건축학회&rt2=서울대학교 자하연">서울대학교 자하연</a></td>
#       <td>0:35:00</td>
#       <td>48</td>
#       <td>6.200</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5-14</th>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,492341.0,1104736.0&rt1=대한건축학회&rt2=JK장평타워">대한건축학회</a></td>
#       <td>0:13:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=bike&rt=492341.0,1104736.0,490806.0,1103490.0&rt1=JK장평타워&rt2=영어마을 관악캠프">JK장평타워</a></td>
#       <td>0:06:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=490806.0,1103490.0,489405.0,1100357.0&rt1=영어마을 관악캠프&rt2=서울대학교 자하연">영어마을 관악캠프</a></td>
#       <td>0:17:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,489405.0,1100357.0&rt1=대한건축학회&rt2=서울대학교 자하연">서울대학교 자하연</a></td>
#       <td>0:36:00</td>
#       <td>39</td>
#       <td>6.800</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2-3</th>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,496967.0,1104595.0&rt1=대한건축학회&rt2=연세사랑병원신관앞">대한건축학회</a></td>
#       <td>0:06:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=bike&rt=496967.0,1104595.0,495872.0,1104626.0&rt1=연세사랑병원신관앞&rt2=사당역 5번출구">연세사랑병원신관앞</a></td>
#       <td>0:03:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=495872.0,1104626.0,489405.0,1100357.0&rt1=사당역 5번출구&rt2=서울대학교 자하연">사당역 5번출구</a></td>
#       <td>0:28:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,489405.0,1100357.0&rt1=대한건축학회&rt2=서울대학교 자하연">서울대학교 자하연</a></td>
#       <td>0:37:00</td>
#       <td>17</td>
#       <td>7.049</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6-16</th>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,491905.0,1104888.0&rt1=대한건축학회&rt2=낙성대역 3번출구 뒤">대한건축학회</a></td>
#       <td>0:16:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=bike&rt=491905.0,1104888.0,490636.0,1102650.0&rt1=낙성대역 3번출구 뒤&rt2=낙성대 교수아파트">낙성대역 3번출구 뒤</a></td>
#       <td>0:07:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=490636.0,1102650.0,489405.0,1100357.0&rt1=낙성대 교수아파트&rt2=서울대학교 자하연">낙성대 교수아파트</a></td>
#       <td>0:14:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,489405.0,1100357.0&rt1=대한건축학회&rt2=서울대학교 자하연">서울대학교 자하연</a></td>
#       <td>0:37:00</td>
#       <td>48</td>
#       <td>6.300</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5-15</th>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,492341.0,1104736.0&rt1=대한건축학회&rt2=JK장평타워">대한건축학회</a></td>
#       <td>0:13:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=bike&rt=492341.0,1104736.0,490744.0,1102676.0&rt1=JK장평타워&rt2=낙성대 과학전시관">JK장평타워</a></td>
#       <td>0:09:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=490744.0,1102676.0,489405.0,1100357.0&rt1=낙성대 과학전시관&rt2=서울대학교 자하연">낙성대 과학전시관</a></td>
#       <td>0:15:00</td>
#       <td><a href="https://map.kakao.com/?map_type=TYPE_MAP&target=transit&rt=498615.0,1105833.0,489405.0,1100357.0&rt1=대한건축학회&rt2=서울대학교 자하연">서울대학교 자하연</a></td>
#       <td>0:37:00</td>
#       <td>53</td>
#       <td>6.300</td>
#       <td>1200</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
